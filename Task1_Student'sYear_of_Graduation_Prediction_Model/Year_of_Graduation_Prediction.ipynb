# %% [markdown]
# #IMPORTING NECESSARLY MODULES FOR MACHINE LEARNING

# %% [markdown]
# ![image](logo.png)

# %% [markdown]
# **Intern Name :Hursh Karnik**

# %% [markdown]
# **Intern Id : IP-2996**

# %% [markdown]
# **DOMAIN NAME: MACHINE LEARNING**

# %% [markdown]
# **OBJECTIVE:To predict the Year of Graduation using the given parameters**

# %% [markdown]
# ## 1 importing the required modules for ML

# %%
import pandas as pd
import numpy as np
import plotly
import os
import seaborn as sns

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'count_attende_by_branch.png', 'count_attende_by_city.png', 'count_attende_by_gender.png', 'count_attende_from_where_know_event.png', 'count_attende_want_to_know_more_info_event.png', 'count_attende_who_recommended.png', 'Count_by_academic_year.png', 'Final Lead Data.xlsx', 'predicted_graduate_year.png', 'Predicted_Year_of_Graduation.csv', 'Predicted_Year_of_Graduation.xlsx', 'Year_of_Graduation_Predi.ipynb']

# %%
df = pd.read_excel('Final Lead Data.xlsx')

# %%
df
# Out:
#          ID   First Name               Email Gender City  \
# 0     68112       ANIKET      aniket@xyz.com    NaN  NaN
# 1     68110    Dhanshree   dhanshree@xyz.com    NaN  NaN
# 2     68108       Dhiraj      dhiraj@xyz.com    NaN  NaN
# 3     68106        Pooja       pooja@xyz.com    NaN  NaN
# 4     68090       Aayush      aayush@xyz.com    NaN  NaN
# ...     ...          ...                 ...    ...  ...
# 5298  25834      Pratik       pratik@xyz.com    NaN  NaN
# 5299  25832       Nikita      nikita@xyz.com    NaN  NaN
# 5300  25830     Ashwini      ashwini@xyz.com    NaN  NaN
# 5301  25828  Jheanna Mae  jheannamae@xyz.com    NaN  NaN
# 5302  25826      Krishna     krishna@xyz.com    NaN  NaN
#
#                      Created Position  \
# 0     04/27/2022 01:41:38 pm      NaN
# 1     04/22/2022 04:08:38 pm      NaN
# 2     04/16/2022 10:31:59 pm      NaN
# 3     04/13/2022 10:05:15 pm      NaN
# 4     03/26/2022 07:02:48 pm      NaN
# ...                      ...      ...
# ...

# %% [markdown]
# **CLEANING OUR DATA BY REMOVING DUPLICATES**

# %% [markdown]
# creating copy of the datafram

# %%
df1 = df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5303 entries, 0 to 5302
# Data columns (total 18 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      5303 non-null   int64
#  1   First Name                                              5303 non-null   object
#  2   Email                                                   5303 non-null   object
#  3   Gender                                                  200 non-null    object
#  4   City                                                    55 non-null     object
#  5   Created                                                 5303 non-null   object
#  6   Position                                                6 non-null      object
#  7   New College Name                                        1818 non-null   object
# ...

# %% [markdown]
# Displaying the duplicated email

# %%
duplicate_emails = df[df.duplicated(subset=['Email'], keep=False)]

# %%
print(duplicate_emails)
print("number of duplicate emails")
print(df['Email'].value_counts())
# Out:
#          ID   First Name               Email Gender City  \
# 0     68112       ANIKET      aniket@xyz.com    NaN  NaN
# 1     68110    Dhanshree   dhanshree@xyz.com    NaN  NaN
# 2     68108       Dhiraj      dhiraj@xyz.com    NaN  NaN
# 3     68106        Pooja       pooja@xyz.com    NaN  NaN
# 4     68090       Aayush      aayush@xyz.com    NaN  NaN
# ...     ...          ...                 ...    ...  ...
# 5298  25834      Pratik       pratik@xyz.com    NaN  NaN
# 5299  25832       Nikita      nikita@xyz.com    NaN  NaN
# 5300  25830     Ashwini      ashwini@xyz.com    NaN  NaN
# 5301  25828  Jheanna Mae  jheannamae@xyz.com    NaN  NaN
# 5302  25826      Krishna     krishna@xyz.com    NaN  NaN
#
#                      Created Position  \
# 0     04/27/2022 01:41:38 pm      NaN
# 1     04/22/2022 04:08:38 pm      NaN
# 2     04/16/2022 10:31:59 pm      NaN
# 3     04/13/2022 10:05:15 pm      NaN
# 4     03/26/2022 07:02:48 pm      NaN
# ...                      ...      ...
# ...

# %% [markdown]
# **Removing All the Duplicates Data ByEmail**

# %%
df1 = df1.drop_duplicates(subset='Email', keep='first')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 18 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Position                                                1 non-null      object
#  7   New College Name                                        831 non-null    object
# ...

# %%
df1.isnull().sum()
# Out:
# ID                                                           0
# First Name                                                   0
# Email                                                        0
# Gender                                                    2693
# City                                                      2754
# Created                                                      0
# Position                                                  2807
# New College Name                                          1977
# Colleges                                                  2146
# Academic Year                                             1725
# Branch/ Specialisation                                    1723
# Other Branch                                              2502
# What is your current academic year?                       2754
# Company Name/ College Name                                2668
# Would you like to know more about us and our programs?       0
# ...

# %% [markdown]
# # Insights From The data__
# __position of the data is all null so we can drop it from our dataframe__
# __branch and other branch can be combined into one branch __
# __college and new college can be combined into one college name__

# %%
df1 = df1.drop('Position',axis =1)

# %%
df1['Branch']= df1['Branch/ Specialisation'] + ' ' + df1['Other Branch']

# %%
l =['Branch/ Specialisation','Other Branch']
df1 = df1.drop(l, axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 16 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   New College Name                                        831 non-null    object
#  7   Colleges                                                662 non-null    object
# ...

# %% [markdown]
# ### now merge the college and new college columns

# %%
df1['College'] = df1['Colleges'] + ' ' + df1['New College Name']
l = ['Colleges','New College Name']
df1 = df1.drop(l,axis =1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 15 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Academic Year                                           1083 non-null   float64
#  7   What is your current academic year?                     54 non-null     object
# ...

# %% [markdown]
# ## Data Visualisation Using Seaborn And Matplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
gender_counts = df1['Gender'].value_counts()
gender_df = pd.DataFrame({
    'Gender': gender_counts.index,
    'Count': gender_counts.values,
})
plt.figure(figsize=(10, 6))
sns.barplot(data=gender_df, x='Gender', y='Count', hue='Gender', dodge=False, legend=False)

for index, row in gender_df.iterrows():
    plt.text(index, row['Count'], row['Count'], color='black', ha="center")
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Count of Attendee by Gender')

# Show the plot
plt.show()

# %% [markdown]
# ### Pair PLOT

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df1)
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 15 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Academic Year                                           1083 non-null   float64
#  7   What is your current academic year?                     54 non-null     object
# ...

# %% [markdown]
# # Lets Do Some More Data Visualisation Using Seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

branch = df1['Branch'].value_counts().keys()
count = df1['Branch'].value_counts().values
labels = [str(val) for val in count]

branch_plot_df = pd.DataFrame({
    'Branch': branch,
    'Count': count,
})

plt.figure(figsize=(22, 22))
sns.set(style="whitegrid")

barplot = sns.barplot(data=branch_plot_df, y='Branch', x='Count', palette='viridis',hue='Branch')

for index, row in branch_plot_df.iterrows():
    barplot.text(row['Count'], index, row['Count'], color='black', va="center")

plt.xlabel('Count')
plt.ylabel('Branch')
plt.title('Count of Attendee by Branch')
plt.show()

# %% [markdown]
# ### attendee by city seaborn visulisation

# %%
city_count = df1['City'].value_counts()
# print(city)
city_df = pd.DataFrame({
    'City': city_count.index,
    'Count': city_count.values,
})
plt.figure(figsize=(20, 20))
sns.set(style="whitegrid")
barplot = sns.barplot(data=city_df, x='City', y='Count', palette='viridis',hue ='City')
for index, row in city_df.iterrows():
    barplot.text(x=index, y=row['Count'], s=row['Count'],color='black', va="center")

plt.xlabel('City')
plt.ylabel('Count')
plt.title('Number of Attendee by City')
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 15 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Academic Year                                           1083 non-null   float64
#  7   What is your current academic year?                     54 non-null     object
# ...

# %% [markdown]
# #### more info by programs data

# %%
more_info = df['Would you like to know more about us and our programs?'].value_counts()
# print(more_info)
frame = pd.DataFrame({
    'Yes/No': more_info.index,
    'count': more_info.values
})
plt.figure(figsize=(20, 20))
sns.set(style="whitegrid")
barplot = sns.barplot(data= frame, x='Yes/No', y='count')
for index, row in frame.iterrows():
    barplot.text(x=index, y=row['count'], s=row['count'], color='black', ha="center")
plt.xlabel('Yes/No')
plt.ylabel('Would you like to know more about us and our programs?')
plt.title('Number of Attendee by More info of program')

plt.show()

# %% [markdown]
# #### more info events

# %%
more_info = df['Are you interested in knowing more about our events?'].value_counts()
# print(more_info)
frame = pd.DataFrame({
    'Yes/No': more_info.index,
    'count': more_info.values
})
plt.figure(figsize=(20, 20))
sns.set(style="whitegrid")
barplot = sns.barplot(data= frame, x='Yes/No', y='count')
for index, row in frame.iterrows():
    barplot.text(x=index, y=row['count'], s=row['count'], color='black', ha="center")
plt.xlabel('Yes/No')
plt.ylabel('Are you interested in knowing more about our events?')
plt.title('Number of Attendee by More info of events')

plt.show()

# %% [markdown]
# #### Have you recommended Cloud Counselage to anyone? data

# %%
more_info = df['Have you recommended Cloud Counselage to anyone?'].value_counts()
# print(more_info)
frame = pd.DataFrame({
    'Yes/No': more_info.index,
    'count': more_info.values
})
plt.figure(figsize=(20, 20))
sns.set(style="whitegrid")
barplot = sns.barplot(data= frame, x='Yes/No', y='count')
for index, row in frame.iterrows():
    barplot.text(x=index, y=row['count'], s=row['count'], color='black', ha="center")
plt.xlabel('Yes/No')
plt.ylabel('Have you recommended Cloud Counselage to anyone?')
plt.title('Number of Attendee by recommendetation')

plt.show()

# %% [markdown]
# #### How did you come to know about this event?

# %%
more_info = df['How did you come to know about this event?'].value_counts()
# print(more_info)
frame = pd.DataFrame({
    'Yes/No': more_info.index,
    'count': more_info.values
})
plt.figure(figsize=(20, 20))
sns.set(style="whitegrid")
barplot = sns.barplot(data= frame, x='Yes/No', y='count')
for index, row in frame.iterrows():
    barplot.text(x=index, y=row['count'], s=row['count'], color='black', ha="center")
plt.xlabel('Yes/No')
plt.ylabel('How did you come to know about this event?')
plt.title('Number of Attendee by knowing of event')

plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 15 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Academic Year                                           1083 non-null   float64
#  7   What is your current academic year?                     54 non-null     object
# ...

# %% [markdown]
# # prediction of Academic year From academic_year and 'What is your current academic year?' column

# %% [markdown]
# ##### this is before academic year

# %%
df1['Academic Year'].value_counts()
#this is before academic year
# Out:
# Academic Year
# 3.0    512
# 2.0    295
# 4.0    214
# 1.0     62
# Name: count, dtype: int64

# %% [markdown]
# ##### this is the What is your current academic year? column

# %%
acad_df =df1['What is your current academic year?'].value_counts()
print(acad_df)
# this is the What is your current academic year? column
# Out:
# What is your current academic year?
# 3rd Year      21
# Final Year    19
# 2nd Year      10
# 1st Year       4
# Name: count, dtype: int64

# %% [markdown]
# ### lets shift the response of attende from  'What is your current academic year?' column to academic year column

# %%
# lets add from What is your current academic year? column to academic year column
academic_yr_dict ={
    '3rd Year': 3,
    'Final Year': 4,
    '2nd Year': 2,
    '1st Year': 1
}
df1['Academic Year'] = df1['Academic Year'].fillna(df1['What is your current academic year?'].map(academic_yr_dict))
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 15 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Academic Year                                           1098 non-null   float64
#  7   What is your current academic year?                     54 non-null     object
# ...

# %%
df1['Academic Year'].value_counts()
# Out:
# Academic Year
# 3.0    515
# 2.0    297
# 4.0    221
# 1.0     65
# Name: count, dtype: int64

# %% [markdown]
# #### replacing  all na values to 0

# %%
df1['Academic Year'] = df1['Academic Year'].fillna(0)
df1['Academic Year'].value_counts()
# Out:
# Academic Year
# 0.0    1710
# 3.0     515
# 2.0     297
# 4.0     221
# 1.0      65
# Name: count, dtype: int64

# %% [markdown]
# ### droping 'What is your current academic year?' as we copied the response from it to academic year

# %%
df1 = df1.drop('What is your current academic year?', axis=1)
df1.info()
# as it can be seen it is droped from our dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 14 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Academic Year                                           2808 non-null   float64
#  7   Company Name/ College Name                              140 non-null    object
# ...

# %% [markdown]
# ## now extract date and year from the created column

# %%
df1['Created'] = pd.to_datetime(df1['Created'])
df1['Month'] = df1['Created'].dt.month
df1['Year'] = df1['Created'].dt.year
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 16 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   datetime64[ns]
#  6   Academic Year                                           2808 non-null   float64
#  7   Company Name/ College Name                              140 non-null    object
# ...

# %%
df1['Academic Year'] = df1['Academic Year'].astype(int)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
academic_year_counts = df1['Academic Year'].value_counts().sort_index()
# print(academic_year_counts) 
academic_year_frame = pd.DataFrame({
    'Academic Year': academic_year_counts.index,
    'Count': academic_year_counts.values
})
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
barplot = sns.barplot(data=academic_year_frame, x='Academic Year', y='Count')

# text on barplot
for index, row in academic_year_frame.iterrows():
    barplot.text(x=index, y=row['Count'], s=row['Count'], color='black', ha="center")
plt.xlabel('Academic Year')
plt.ylabel('Number of Students')
plt.title('Number of Students by Academic Year')
plt.show()

# %% [markdown]
# ## Now lets predict the year of graduation
# #### as we know students are engineering student so their course duration is of 4 years

# %%
predicted_grad_year = []
for i in range(len(df1)):
    acad_year = df1.iloc[i]['Academic Year']
    curr_year = df1.iloc[i]['Year']
    if acad_year != 0:
        if acad_year == 1:
            predicted_grad_year.append(3 + curr_year)
        elif acad_year == 2:
            predicted_grad_year.append(2 + curr_year)
        elif acad_year == 3:
            predicted_grad_year.append(1 + curr_year)
        elif acad_year == 4:
            predicted_grad_year.append(curr_year)
    else:
        predicted_grad_year.append(0)
        
df1['Year of Graduation'] = predicted_grad_year
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   datetime64[ns]
#  6   Academic Year                                           2808 non-null   int32
#  7   Company Name/ College Name                              140 non-null    object
# ...

# %% [markdown]
# ### now lets blank the year of graduation where graduation_year is 0

# %%
df1['Year of Graduation'] = df1['Year of Graduation'].replace({0 : ' '})
df1['Year of Graduation'].info()
print(df1['Year of Graduation'])
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2808 entries, 0 to 5260
# Series name: Year of Graduation
# Non-Null Count  Dtype
# --------------  -----
# 2808 non-null   object
# dtypes: object(1)
# memory usage: 43.9+ KB
# 0
# 1
# 2
# 3
# 4
#         ...
# 5250
# 5255    2020
# 5256    2020
# 5258
# 5260
# Name: Year of Graduation, Length: 2808, dtype: object

# %% [markdown]
# ## lets  perform some data visulisation

# %%
yr = df1['Year of Graduation'].value_counts()
print(yr)
year_frame = pd.DataFrame({
    'Year':yr.index,
    'Count': yr.values
})
plt.figure(figsize=(20, 20))
sns.set(style="whitegrid")
barplot = sns.barplot(data=year_frame, y='Count', x='Year',order=year_frame['Year'])
for index, row in year_frame.iterrows():
    barplot.text(x=index, y=row['Count'], s=str(row['Count']), color='black', ha="center")
plt.xlabel('graduation_Year')
plt.ylabel('number of student')
plt.title('Predicted year of graduation of student')

plt.show()
# Out:
# Year of Graduation
#         1710
# 2021     430
# 2022     344
# 2020     151
# 2023     149
# 2024      21
# 2019       3
# Name: count, dtype: int64

# %% [markdown]
# ## end of task1: by creating excel sheet

# %%
df1.to_excel('Predicted_Year_of_Graduation.xlsx')
df.to_csv('Predicted_Year_of_Graduation.csv')
